# %%
import numpy as np
import pandas as pd

# %%
labels = ['a','b','c']
my_data = [10,20,30]
arr = np.array(my_data)
d = {'a':10,'b':20,'c':30}

# %%
pd.Series(data=my_data)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(data=my_data,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
ser1 = pd.Series([1,2,3,4],['USA','Germany','USSR','Japan'])

# %%
ser1['USSR']
# Out:
# 3

# %% [markdown]
# ### DataFrame

# %%
from numpy.random import randn
np.random.seed(101)

# %%
df = pd.DataFrame(randn(5,4),['A','B','C','D','E'],['W','X','Y','Z'])

# %%
df['W']
# Out:
# A    0.302665
# B   -0.134841
# C    0.807706
# D   -0.497104
# E   -0.116773
# Name: W, dtype: float64

# %%
df[['W','X']]
# Out:
#           W         X
# A  0.302665  1.693723
# B -0.134841  0.390528
# C  0.807706  0.072960
# D -0.497104 -0.754070
# E -0.116773  1.901755

# %%
df['new'] = df['W'] + df['X']

# %%
df.drop('new', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-86cccbfbaff1> in <module>()
# ----> 1 df.drop('new', axis=1, inplace=True)
#
# /Users/slechwar/miniconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in drop(self, labels, axis, level, inplace, errors)
#    2048                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2049             else:
# -> 2050                 new_axis = axis.drop(labels, errors=errors)
#    2051             dropped = self.reindex(**{axis_name: new_axis})
#    2052             try:
#
# /Users/slechwar/miniconda2/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in drop(self, labels, errors)
#    3573             if errors != 'ignore':
#    3574                 raise ValueError('labels %s not contained in axis' %
# -> 3575                                  labels[mask])
#    3576             indexer = indexer[~mask]
#    3577         return self.delete(indexer)
#
# ValueError: labels ['new'] not contained in axis

# %%
# Rows

# %%
df.loc['A']
# Out:
# W    0.302665
# X    1.693723
# Y   -1.706086
# Z   -1.159119
# Name: A, dtype: float64

# %%
df.iloc[2]
# Out:
# W    0.807706
# X    0.072960
# Y    0.638787
# Z    0.329646
# Name: C, dtype: float64

# %%
df.loc['B','Y']
# Out:
# 0.16690463609281317

# %%
df.loc[['A','B'],['W','Y']]
# Out:
#           W         Y
# A  0.302665 -1.706086
# B -0.134841  0.166905

# %%
df[df > 0]
# Out:
#           W         X         Y         Z
# A  0.302665  1.693723       NaN       NaN
# B       NaN  0.390528  0.166905  0.184502
# C  0.807706  0.072960  0.638787  0.329646
# D       NaN       NaN       NaN  0.484752
# E       NaN  1.901755  0.238127  1.996652

# %%
df[df['W'] > 0]
# Out:
#           W         X         Y         Z
# A  0.302665  1.693723 -1.706086 -1.159119
# C  0.807706  0.072960  0.638787  0.329646

# %%
# all rows where Z is less than 0
df[df['Z'] < 0][['Y', 'Z']]
# Out:
#           Y         Z
# A -1.706086 -1.159119

# %%
# multiple conditions
df[(df['W'] > 0) & (df['Z'] < 0)]
# Out:
#           W         X         Y         Z
# A  0.302665  1.693723 -1.706086 -1.159119

# %%
df
# Out:
#           W         X         Y         Z
# A  0.302665  1.693723 -1.706086 -1.159119
# B -0.134841  0.390528  0.166905  0.184502
# C  0.807706  0.072960  0.638787  0.329646
# D -0.497104 -0.754070 -0.943406  0.484752
# E -0.116773  1.901755  0.238127  1.996652

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#           W         X         Y         Z
# 0  0.302665  1.693723 -1.706086 -1.159119
# 1 -0.134841  0.390528  0.166905  0.184502
# 2  0.807706  0.072960  0.638787  0.329646
# 3 -0.497104 -0.754070 -0.943406  0.484752
# 4 -0.116773  1.901755  0.238127  1.996652

# %%
newid = 'CA NY WY OR CO'.split()

# %%
df['States'] = newid

# %%
df.set_index('States')
# Out:
#                W         X         Y         Z
# States
# CA      0.302665  1.693723 -1.706086 -1.159119
# NY     -0.134841  0.390528  0.166905  0.184502
# WY      0.807706  0.072960  0.638787  0.329646
# OR     -0.497104 -0.754070 -0.943406  0.484752
# CO     -0.116773  1.901755  0.238127  1.996652

# %%
# multi-index
outside = 'G1 G1 G1 G2 G2 G2 G2'.split()
inside = [1,2,3,1,2,3]

hier_index = list(zip(outside, inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)

# %%
df = pd.DataFrame(randn(6,2), hier_index, ['A', 'B'])

# %%
df.loc['G1'].loc[1:2, 'A']
# Out:
# 1    0.992573
# 2   -1.046780
# Name: A, dtype: float64

# %%
#### MISSING DATA

# %%
d = {'A': [1, 2, np.nan],
     'B': [5, np.nan, np.nan],
     'C': [1, 2, 3]}
df = pd.DataFrame(d)

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(axis=1)
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
df.fillna(value='FILL VALUE')
# Out:
#             A           B  C
# 0           1           5  1
# 1           2  FILL VALUE  2
# 2  FILL VALUE  FILL VALUE  3

# %%
df['A'].fillna(value=df['A'].mean())
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %%
#### GROUPBY

# %%
d = {'Company': ['GOOG', 'GOOG', 'MSFT', 'MSFT', 'FB', 'FB'],
     'Person': ['Sam', 'Charlie', 'Amy', 'Vanessa', 'Carl', 'Sarah'],
     'Sales': [200, 120, 340, 124, 243, 350]}
df = pd.DataFrame(d)

# %%
df.groupby(['Company']).max().loc['FB']
# Out:
# Person    Sarah
# Sales       350
# Name: FB, dtype: object

# %%
#### Merging, joining and concat
